# %% [markdown]
# # scArches cross-species transfer learning

# %%
import os
os.chdir('../')
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

import scanpy as sc
import torch
import scarches as sca
from scarches.dataset.trvae.data_handling import remove_sparsity
import matplotlib.pyplot as plt
import numpy as np
import gdown

sc.settings.set_figure_params(dpi=200, frameon=False)
sc.set_figure_params(dpi=200)
sc.set_figure_params(figsize=(4, 4))
torch.set_printoptions(precision=3, sci_mode=False, edgeitems=7)

# %%
moc2 = sc.read('/Volumes/hdlab/Projects/HNC_SPORE/Mouse_to_human_comparsion/scArches_comparison/moc2_seurat.h5ad')
moc2

hnc = sc.read('/Volumes/hdlab/Projects/HNC_SPORE/Mouse_to_human_comparsion/scArches_comparison/hnc_human_seurat.h5ad')
hnc
# Out:
# AnnData object with n_obs × n_vars = 60976 × 2000
#     obs: 'orig.ident', 'nCount_RNA', 'nFeature_RNA', 'seurat_clusters', 'RNA_snn_res.0.5', 'RNA_snn_res.0.6', 'RNA_snn_res.0.7', 'RNA_snn_res.0.8', 'RNA_snn_res.0.9', 'RNA_snn_res.1', 'RNA_snn_res.1.1', 'RNA_snn_res.1.2', 'RNA_snn_res.1.3', 'RNA_snn_res.1.4', 'RNA_snn_res.1.5', 'RNA_snn_res.1.6', 'RNA_snn_res.1.7', 'RNA_snn_res.1.8', 'RNA_snn_res.1.9', 'RNA_snn_res.2', 'tissue', 'is_HD', 'global.cluster', 'global.cluster2', 'hpv_status', 'RNA_snn_res.2.1', 'RNA_snn_res.2.2', 'RNA_snn_res.2.3', 'RNA_snn_res.2.4', 'RNA_snn_res.2.5', 'RNA_snn_res.2.6', 'RNA_snn_res.2.7', 'RNA_snn_res.2.8', 'RNA_snn_res.2.9', 'RNA_snn_res.3', 'tissue_hpv', 'global.cluster4', 'global.cluster5', 'AEG_global.cluster'
#     var: 'vst.mean', 'vst.variance', 'vst.variance.expected', 'vst.variance.standardized', 'vst.variable'
#     obsm: 'X_harmony', 'X_pca', 'X_umap'
#     varm: 'HARMONY', 'PCs'

# %%
sca.dataset.setup_anndata(hnc, batch_key= 'orig.ident', labels_key = 'global.cluster4')
# Out:
# INFO     Using batches from adata.obs["orig.ident"]
# INFO     Using labels from adata.obs["global.cluster4"]
# INFO     Using data from adata.X
# INFO     Successfully registered anndata object containing 60976 cells, 2000 vars, 26
#          batches, 28 labels, and 0 proteins. Also registered 0 extra categorical covariates
#          and 0 extra continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %%
vae = sca.models.SCVI(hnc)

# %%
vae.train()
#array_sum = np.sum(hnc.X)
#array_has_nan = np.isnan(array_sum)
#print(array_sum)
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# Epoch 1/131:   0%|          | 0/131 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-a64959953ca9> in <module>
# ----> 1 vae.train()
#       2 #array_sum = np.sum(hnc.X)
#       3 #array_has_nan = np.isnan(array_sum)
#       4 #print(array_sum)
#
# /opt/anaconda3/lib/python3.8/site-packages/scvi/model/base/_training_mixin.py in train(self, max_epochs, use_gpu, train_size, validation_size, batch_size, early_stopping, plan_kwargs, **trainer_kwargs)
#      75             **trainer_kwargs,
#      76         )
# ---> 77         return runner()
#
# /opt/anaconda3/lib/python3.8/site-packages/scvi/train/_trainrunner.py in __call__(self)
#      70             self.training_plan.n_obs_training = self.data_splitter.n_train
#      71
# ...
